# %% [markdown]
# # Assigment 3
#
# ### Instructions
# - Do NOT change the filename.
# - Do NOT add or copy cells before the "Sandpit". Only add your own cells after the "Sandpit".
# - Enter your name below.

# %% [markdown]
# ### Enter your name here
# Name: CHANGE ME

# %% [markdown]
# # **Optional** Task 4 (5 bonus points)
#
# **Important requirements**
# - No loops are allowed for this task.
#
# Violating any of the requirements will score **ZERO** points.

# %% [markdown]
# Write a function that returns, in a list, all the primes from min to a given max (inclusive) number.
#
# You can assume that min is at least 2, i.e. we will never call the function with min = 1.
#
# Here are some sample outputs:
#
# ```
#     primes(2, 5) --> [2, 3, 5]
#     primes(10, 15) --> [11, 13]
# ```

# %%
def primes(min, max):
    # YOUR CODE HERE
    raise NotImplementedError()

# %% [markdown]
# # Tests
#
# The cell below contains unit tests for your solution.
#
# Run the below cell (after running all the above cells with your code).

# %%
assert primes(2, 5) == [2, 3, 5]

# %%
assert primes(10, 15) == [11, 13]

# %%
# Hidden tests

# %%
# Hidden tests

# %%
# Hidden tests

# %% [markdown]
# # Sandpit begins here
# ### Add your own cells below
