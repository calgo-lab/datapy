# %% [markdown]
# # Assigment 3
#
# ### Instructions
# - Do NOT change the filename.
# - Do NOT add or copy cells before the "Sandpit". Only add your own cells after the "Sandpit".
# - Enter your name below.

# %% [markdown]
# ### Enter your name here
# Name: CHANGE ME

# %% [markdown]
# # Task 2 (6 points)
#
# **Important requirements**
# - No loops are allowed for this task.
# - The body of each function must be only **one** line of code.
#
# Violating any of the requirements will score **ZERO** points for the corresponding function.

# %% [markdown]
# You are given the following dictionary of sets:

# %%
prog_skills = {
    "Anna": {"C#", "Java"},
    "Bob": {"Python", "C++", "JavaScript"},
    "Carla": {"Java", "JavaScript", "Python"},
}

# %% [markdown]
# Using this dictionary, write a function that returns the answer to each of the questions below. The returned string should follow the format of the expected return value below.

# %% [markdown]
# ### Question 1: What language(s) can a person code in?
#
# For Carla, expected return value is:
# ``Carla can code in Java and JavaScript and Python.``
#
# Hint: Google joining strings with a separator.
#
# (Order of items in a set may vary, and that's just fine.)

# %%
def question1(dictionary, person):
    # YOUR CODE HERE
    raise NotImplementedError()

# %% [markdown]
# ### Question 2: How many language(s) can a person code in?
#
# For Bob, expected return value is:
# ``Bob codes in 3 languages.``

# %%
def question2(dictionary, person):
    # YOUR CODE HERE
    raise NotImplementedError()

# %% [markdown]
# ### Question 3: What language(s) do both person 1 and person 2 code in?
#
# For Anna and Carla, expected return value is:
# ``They both code in Java.``
#
# For Bob and Carla, expected return value is:
# ``They both code in Java and JavaScript.``
#
# (Order of items in a set may vary, and that's just fine.)

# %%
def question3(dictionary, person1, person2):
    # YOUR CODE HERE
    raise NotImplementedError()

# %% [markdown]
# # Tests
#
# The cell below contains unit tests for your solution.
#
# Run the below cell (after running all the above cells with your code).

# %%
assert question1(prog_skills, "Anna") == "Anna can code in C# and Java." or \
question1(prog_skills, "Anna") == "Anna can code in Java and C#."

# %%
# Hidden tests

# %%
assert question2(prog_skills, "Bob") == "Bob codes in 3 languages."

# %%
# Hidden tests

# %%
assert question3(prog_skills, "Anna", "Carla") == "They both code in Java."

# %%
# Hidden tests

# %% [markdown]
# # Sandpit begins here
# ### Add your own cells below
