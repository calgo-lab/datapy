# %% [markdown]
# # Data Types

# %% [markdown]
# # Python Variables
#
# - are assigned with ```=```
# - are *dynamically typed* (have no static type)
# - are pointers
# - variable names:
#     - must begin with a letter (lower or upper case) or underscore _
#     - may contain letters, numbers and underscore, but cannot begin with a number
#     - are case sensitive

# %% [markdown]
# ## Python Variables are assigned with ```=```

# %%
# assign 4 to the variable x
x = 4
x
# Out:
# 4

# %% [markdown]
# ## Python Variables are passed-by-reference
# In contrast, Java variables are passed-by-value

# %%
x = 3.1415   # define a container in memory with value 3.1415 and assign variable/pointer x to it
y = x        # assign a second variable y that points to the same location as x
print(x)
print(y)
print(id(x)) # address of the container x is pointing at
print(id(y))
# Out:
# 3.1415
# 3.1415
# 140276064174128
# 140276064174128

# %%
x = 2.71     # define a new container with value 2.71 and reassign pointer x to the new location
print(x)
print(y)
print(id(x))
print(id(y))
# Out:
# 2.71
# 3.1415
# 140276064176976
# 140276064174128

# %% [markdown]
# **Note**: Java would have modified the same container *x* changing the value 3.1415 to 2.71.
#
# In contrast, Python creates 2 containers (one with value 3.1415, one with value 2.71) and just reassigns the pointer *x*.

# %%
# Bonus:
x += 3       # this also creates another container with the value 2.71 + 3 = 5.71
print(x)
print(id(x))
# Out:
# 5.71
# 140276064466064

# %% [markdown]
# Note: Python differentiates between **immutable** objects (``int``, ``float``, ``bool``, ``str``, ``tuple``) and **mutable** ones (``list``, ``dict``, ``set``).
#
# More on this later.

# %% [markdown]
# ## Python Variables are 'dynamically typed'

# %%
x = 1         # x is an integer
print(x)
x = 'hello'   # now x is a string
print(x)
x = [1, 2, 3] # now x is a list
print(x)
# Out:
# 1
# hello
# [1, 2, 3]

# %% [markdown]
# ## Dynamic Typing
#
# - Type only known at runtime
# - Can result in semantic errors

# %%
# a function for multiplying numbers by two:
def multiply_by_two(x):
    return x * 2

x = 2 # x is an integer
print(multiply_by_two(x))
# Out:
# 4

# %%
x = "2" # x is a string
print(multiply_by_two(x))
# Out:
# 22

# %%
xx = [3,3]
xx * 3
# Out:
# [3, 3, 3, 3, 3, 3]

# %% [markdown]
# - 'Normal' (that is *static*) typing: variable is declared to be of certain type
# ```
# int c = 0;
# ```
#
# - Python does not have variables with static types (but see [mypy](http://mypy-lang.org/examples.html))

# %% [markdown]
# ## How to check types by introspection

# %%
x = 1         # x is an integer
type(x)
# Out:
# int

# %%
x = "1"         # x is a string
type(x)
# Out:
# str

# %%
x = [1]         # x is a list
type(x)
# Out:
# list

# %%
x = [1]         # x is a list
issubclass(type(x), list)
# Out:
# True

# %% [markdown]
# # Python Scalar Types
#
# | Type        | Example        | Description                                                  |
# |-------------|----------------|--------------------------------------------------------------|
# | ``int``     | ``x = 1``      | integers (i.e., whole numbers)                               |
# | ``float``   | ``x = 1.0``    | floating-point numbers (i.e., real numbers)                  |
# | ``complex`` | ``x = 1 + 2j`` | Complex numbers (i.e., numbers with real and imaginary part) |
# | ``bool``    | ``x = True``   | Boolean: True/False values                                   |
# | ``str``     | ``x = 'abc'``  | String: characters or text                                   |
# | ``NoneType``| ``x = None``   | Special object indicating nulls                              |

# %% [markdown]
# *Note 1*: Python 2 had an extra type `long` for very large values, which got replaced by `int` in Python 3.

# %% [markdown]
# *Note 2*: There is no size limit to the Python 3 `int` - you can theoretically run out of memory by adding integers :^)

# %% [markdown]
# ## Integers

# %%
x = 1
type(x)
# Out:
# int

# %%
# python ints are automatically casted to floats
x / 2
# Out:
# 0.5

# %% [markdown]
# ## Floats

# %%
x = 1
type(x)
# Out:
# int

# %%
# explicit cast
x = float(1)
type(x)
# Out:
# float

# %%
type(1.)
# Out:
# float

# %%
# equality checks between floats and ints actually work
1. == 1
# Out:
# True

# %% [markdown]
# ### Exponential notation
#
# ``e`` or ``E`` can be read "...times ten to the...",
# so that ``1.4e6`` is interpreted as $~1.4 \times 10^6$

# %%
x = 1400000.00
y = 1.4e6
print(x == y)
# Out:
# True

# %% [markdown]
# Fun facts:
# - maximum float value on a 64-bit computer: `1.7976931348623157e+308`
# - minimum float value: `2.2250738585072014e-308`
# - Python floats use *double precision* with 53 bits -> precision up to 16 digits; if you need more, use `Decimal`
# - computers are binary machines -> floats are stored as integers and then divided by a power of 2, more infos [here](http://docs.python.org/tutorial/floatingpoint.html)

# %% [markdown]
# ## None Type
# Similar to null in Java

# %%
return_value = print('abc')
type(return_value)
# Out:
# abc
# NoneType

# %% [markdown]
# ## Boolean Type
#
# - ```True``` and ```False```
# - Case sensitive!

# %%
result = (4 < 5)
result
# Out:
# True

# %%
type(result)
# Out:
# bool

# %% [markdown]
# ### Many types are implicitly cast to booleans:

# %% [markdown]
# ### Numbers

# %%
bool(2014)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %% [markdown]
# ### None Types (or any other Type)

# %%
bool(None)
# Out:
# False

# %% [markdown]
# ### Strings

# %%
bool("")
# Out:
# False

# %%
bool("abc")
# Out:
# True

# %% [markdown]
# ### Lists

# %%
bool([1, 2, 3])
# Out:
# True

# %%
x = [3,[3]]
y = [3]
y in x
# Out:
# True

# %% [markdown]
# # Operators
# - Arithmetic Operators
# - Bitwise Operators
# - Assignment Operators
# - Comparison Operators
# - Boolean Operators
# - Membership Operators

# %% [markdown]
# ## Arithmetic Operations
#
# | Operator     | Name           | Description                                            |
# |--------------|----------------|--------------------------------------------------------|
# | ``a + b``    | Addition       | Sum of ``a`` and ``b``                                 |
# | ``a - b``    | Subtraction    | Difference of ``a`` and ``b``                          |
# | ``a * b``    | Multiplication | Product of ``a`` and ``b``                             |
# | ``a / b``    | True division  | Quotient of ``a`` and ``b``                            |
# | ``a // b``   | Floor division | Quotient of ``a`` and ``b``, removing fractional parts |
# | ``a % b``    | Modulus        | Integer remainder after division of ``a`` by ``b``     |
# | ``a ** b``   | Exponentiation | ``a`` raised to the power of ``b``                     |
# | ``-a``       | Negation       | The negative of ``a``                                  |
# | ``+a``       | Unary plus     | ``a`` unchanged (rarely used)                          |

# %%
a = 12
b = 3
a + b
# Out:
# 15

# %%
# Operator precedence
print(a + b / 3 - 4 * 12)
# Out:
# -35.0

# %% [markdown]
# ## Bitwise Operations
#
# | Operator     | Name            | Description                                 |
# |--------------|-----------------|---------------------------------------------|
# | ``a & b``    | Bitwise AND     | Bits defined in both ``a`` and ``b``        |
# | <code>a &#124; b</code>| Bitwise OR      | Bits defined in ``a`` or ``b`` or both      |
# | ``a ^ b``    | Bitwise XOR     | Bits defined in ``a`` or ``b`` but not both |
# | ``a << b``   | Bit shift left  | Shift bits of ``a`` left by ``b`` units     |
# | ``a >> b``   | Bit shift right | Shift bits of ``a`` right by ``b`` units    |
# | ``~a``       | Bitwise NOT     | Bitwise negation of ``a``                          |

# %%
a = True
b = False
a & b
# Out:
# False

# %% [markdown]
# ## Assignment Operations
#
# | $~ $     | $~ $           | $~ $                                 |
# |--------------|-----------------|---------------------------------------------|
# |``a += b``| ``a -= b``|``a *= b``| ``a /= b``|
# |``a //= b``| ``a %= b``|``a **= b``|``a &= b``|
# |<code>a &#124;= b</code>| ``a ^= b``|``a <<= b``| ``a >>= b``|

# %%
a = 2
print(id(a))

# 'Normal' Assignment
a = a + 2  # equivalent to a = a + 2, but more efficient (it only evaluates 'a' once)

print(a)
print(id(a)) # new address
# Out:
# 140276047997264
# 4
# 140276047997328

# %%
a = 2
print(id(a))

# Augmented Assignment
a += 2  # equivalent to a = a + 2, but more efficient (it only evaluates 'a' once)

# However: still new container created (integers are immutable)

print(a)
print(id(a)) # new address
# Out:
# 140276047997264
# 4
# 140276047997328

# %% [markdown]
# ## Boolean Operations
#
# | Operator      | Description                                       |
# |---------------|---------------------------------------------------|
# | ``a and b``    | True if ``a`` and ``b``     |
# | ``a or b``| True if ``a`` or ``b`` is true |
# | ``not a``    | True if ``a`` is false.|

# %%
True and False
# Out:
# False

# %%
[True, True] or [False, True]
# Out:
# [True, True]

# %%
[True, True, True] and [True, False, 2]
# Out:
# [True, False, 2]

# %% [markdown]
# How does ``and`` and ``or`` process non-boolean values?
# See https://stackoverflow.com/questions/47007680/how-do-and-and-or-act-with-non-boolean-values

# %% [markdown]
# ## Comparison Operations
#
# | Operation     | Description                       | Operation     | Description                          |
# |---------------|-----------------------------------|---------------|--------------------------------------|
# | ``a == b``    | ``a`` equal to ``b``              | ``a != b``    | ``a`` not equal to ``b``             |
# | ``a < b``     | ``a`` less than ``b``             | ``a > b``     | ``a`` greater than ``b``             |
# | ``a <= b``    | ``a`` less than or equal to ``b`` | ``a >= b``    | ``a`` greater than or equal to ``b`` |

# %%
# 25 is odd
25 % 2 == 1
# Out:
# True

# %%
# check if a is between 15 and 30
a = 25
15 < a < 30
# Out:
# True

# %%
# comparisons on standard collections are not elementwise
[1,3] == [2,2]
# Out:
# False

# %%
# but
a = [1,2]
b = a
a == b
# Out:
# True

# %%
# Check if the address is the same
a is b
# Out:
# True

# %%
c = [1,2]
c is a
# Out:
# False

# %% [markdown]
# ## Identity and Membership Operators
#
# | Operator      | Description                                       |
# |---------------|---------------------------------------------------|
# | ``a is b``    | True if ``a`` and ``b`` are identical objects     |
# | ``a is not b``| True if ``a`` and ``b`` are not identical objects |
# | ``a in b``    | True if ``a`` is a member of ``b``                |
# | ``a not in b``| True if ``a`` is not a member of ``b``            |

# %%
1 in [1,2,3]
# Out:
# True

# %% [markdown]
# ## Strings
#
# - Python is great for Strings
# - String encoding is a good reason to not use Python 2

# %% [markdown]
# ### Some Useful String Functions

# %%
message = "The answer is "
answer = '42'

# %%
# length of string
len(answer)
# Out:
# 2

# %%
# Make upper-case. See also str.lower()
message.upper()
# Out:
# 'THE ANSWER IS '

# %%
# Concatenation 
message + answer
# Out:
# 'The answer is 42'

# %%
# Multiple arguments
print(message, answer)
# Out:
# The answer is  42

# %%
# All arguments must be strings when concatenating
answer2 = 42
print(message, answer2)       # this works
print(message + str(answer2)) # this, too
# Out:
# The answer is  42
# The answer is 42

# %% [markdown]
# ```python
# print(message + answer2)      # this doesn't
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 5
#       3 print(message, answer2)       # this works
#       4 print(message + str(answer2)) # this, too
# ----> 5 print(message + answer2)      # this doesn't
#
# TypeError: can only concatenate str (not "int") to str```

# %%
# String-multiplication
answer * 3
# Out:
# '424242'

# %%
# Finding substrings
line = 'the quick brown fox jumped over a lazy dog'
line.find('fox')
# Out:
# 16

# %%
line.find('bear')
# Out:
# -1

# %%
# Simple replacements
line.replace('brown', 'red')
# Out:
# 'the quick red fox jumped over a lazy dog'

# %%
# Splitting a sentence into words
line.split()
# Out:
# ['the', 'quick', 'brown', 'fox', 'jumped', 'over', 'a', 'lazy', 'dog']

# %%
# Joining them back together
'--'.join(line.split())
# Out:
# 'the--quick--brown--fox--jumped--over--a--lazy--dog'

# %% [markdown]
# ### String Formatting

# %%
x = 3.14159
"Bad approximation of pi: " + str(x)
# Out:
# 'Bad approximation of pi: 3.14159'

# %%
"Bad approximation of pi: {}".format(x)
# Out:
# 'Bad approximation of pi: 3.14159'

# %% [markdown]
# ### Since Python 3.6: f-String interpolation

# %%
f'Bad approximation {x}'
# Out:
# 'Bad approximation 3.14159'

# %%
x = 3.14
f'Pi is {x}.'
# Out:
# 'Pi is 3.14.'

# %% [markdown]
# # Data Structures

# %% [markdown]
# ## Built-in Python Data Structures
#
# | Type Name | Example                          | Index Access | Mutable | Duplicates   |
# |-----------|----------------------------------|--------------|---------|--------------|
# | ``list``  | ``[1, 2, 3, 2]``                 | Yes          | Yes     | Yes          |
# | ``tuple`` | ``(1, 2, 3, 2)``                 | Yes          | No      | Yes          |
# | ``dict``  | ``{'a':1, 'b':2, 'c':3, 'd':2}`` | No           | Yes     | Yes (Values) |
# | ``set``   | ``{1, 2, 3, 4}``                 | No           | Yes     | No           |

# %% [markdown]
# Note: *lists*, *tuples* (and also *ranges* and *strings*) are commonly known as **Python Sequences** (= **ordered** collections of items).

# %% [markdown]
# ## Lists
#
# - Ordered, indexable
# - Zero-based indexing
# - Mutable
# - Can contain duplicates
# - Defined by ``[ ]``

# %% [markdown]
# ### List Indexing - Accessing Single Elements

# %%
L = [2, 3, 5, 7, 11]
L[0]
# Out:
# 2

# %%
L[-1]
# Out:
# 11

# %%
L[-2]
# Out:
# 7

# %%
# Length of the list
len_L = len(L)
len_L
# Out:
# 5

# %% [markdown]
# ### List Slicing - Accessing Multiple Elements

# %%
L[0:3]
# Out:
# [2, 3, 5]

# %%
L[:len_L]
# Out:
# [2, 3, 5, 7, 11]

# %%
L[:3]
# Out:
# [2, 3, 5]

# %%
L[-3:]
# Out:
# [5, 7, 11]

# %%
L[-3:-1]
# Out:
# [5, 7]

# %%
# Slicing with steps
L[0:5:2]
# Out:
# [2, 5, 11]

# %%
L[-1: :-2]
# Out:
# [11, 5, 2]

# %%
L[::2]  # equivalent to L[0:len(L):2]
# Out:
# [2, 5, 11]

# %%
L[::-1] # reverses a list
# Out:
# [11, 7, 5, 3, 2]

# %% [markdown]
# ### List Indexing and Slicing for Accessing and Assigning Elements

# %%
L[0] = 100
L
# Out:
# [100, 3, 5, 7, 11]

# %%
L[1:3] = [55, 56]
L
# Out:
# [100, 55, 56, 7, 11]

# %% [markdown]
# ### Operations with Lists

# %%
L + [20, 30] # Concatenation
# Out:
# [100, 55, 56, 7, 11, 20, 30]

# %%
L - [2] # Sorry, no subtraction :^(
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 L - [2] # Sorry, no subtraction :^(
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
L.append(10) # Add '10' at the end
L

# %%
L.pop(-1) # Remove last item
L

# %%
L.remove(7) # Remove item '3'
L

# %%
L.insert(3, 1) # Insert 1 at position 3
L

# %%
L.sort() # sorts a list in-place (no copy created)
print(L)
L.sort(reverse=True)
print(L)

# %%
sorted_L = sorted(L) # sorts the list and returns a copy
print(L)
print(sorted_L)

# %%
# Copy a list
L2 = L.copy()
L2

# %% [markdown]
# There are 12 ways of copying a list in Python, some more efficient than others:
#
# https://stackoverflow.com/questions/2612802/how-do-i-clone-a-list-so-that-it-doesnt-change-unexpectedly-after-assignment/43220129#43220129

# %% [markdown]
# ### Pointers to Lists: Shallow vs Deep Copies

# %% [markdown]
# #### Scenario 1

# %%
# What's happening here?
a = [1, 2, 3, 5] 
print(a)
b = a       
print(b)    
a = a + [8] 
            
print(a)    
print(b)

# %% [markdown]
# #### Scenario 1

# %%
# What's happening here?
a = [1, 2, 3, 5] # Define a list container and point at it through pointer a
print(a)
b = a       # A new pointer b pointing to the same container as pointer a
print(b)    # Pointer b points to the same container as a
a = a + [8] # From right to left: access container from a, extend it with '8', store somewhere else in memory 
            # and reassign pointer a to the new location 
print(a)    # Pointer a points to the new extended container
print(b)    # Pointer b points to the original container

# %% [markdown]
# *Note*: Adding / concatenating lists together via `+` creates a new list.

# %% [markdown]
# #### Scenario 1.1

# %%
# What's happening here?
a = [1, 2, 3, 5] 
print(a)
b = a       
print(b)    
a += [8]    

print(a)    
print(b)

# %% [markdown]
# #### Scenario 1.1

# %%
# What's happening here?
a = [1, 2, 3, 5] # Define a list container and point at it through pointer a
print(a)
b = a       # A new pointer b pointing to the same container as pointer a
print(b)    # Pointer b points to the same container as a
a += [8]    # Augmented Assignment: the original container is modified in-place without creating a new one

print(a)    # Pointer a points to the original (now extended) container
print(b)    # Pointer b points to the original (now extended) container

# %% [markdown]
# #### Scenario 2

# %%
# What's happening here?
a = [1, 2, 3, 5] 
print(a)
b = a       
print(b)    
a.append(8)          
print(a)    
print(b)

# %% [markdown]
# #### Scenario 2

# %%
# What's happening here?
a = [1, 2, 3, 5] # Define a list container and point at it through pointer a
print(a)
b = a       # A new pointer b pointing to the same container as pointer a
print(b)    # Pointer b points to the same container as a
a.append(8) # Access container from a and append value '8' to the same container / in the same location
print(a)    # Pointer a points to the same modified container
print(b)    # Pointer b also points to the same modified container

# %% [markdown]
# *Note*: Applying list-specific methods on list objects (`append`, `pop`, `insert`...) does NOT create a new container in memory; the same old container is being modified.

# %% [markdown]
# #### Scenario 3

# %%
# What's happening here?
a = [1, 2, 3, 5] 
print(a)
b = a       
print(b)    
b[0] = 7        
print(a)    
print(b)

# %% [markdown]
# #### Scenario 3

# %%
# What's happening here?
a = [1, 2, 3, 5] # Define a list container and point at it through pointer a
print(a)
b = a     # A new pointer b pointing to the same container as pointer a
print(b)  # Pointer b points to the same container as a
b[0] = 7  # Modify first item in the container via pointer b
print(a)  # Pointer a points to the same modified container
print(b)  # Pointer b also points to the same modified container

# %% [markdown]
# *Note*: Accessing list items through `[ ]` operates directly on the same container; no copies created.

# %% [markdown]
# #### Scenario 4

# %%
# What's happening here?
a = [1, 2, 3, 5] 
print(a)
b = a[:]    
print(b)    
b[0] = 7        
print(a)    
print(b)

# %% [markdown]
# #### Scenario 4

# %%
# What's happening here?
a = [1, 2, 3, 5] # Define a list container and point at it through pointer a
print(a)
b = a[:]  # !!! Create a copy of the container, store somewhere else in memory and point at it via pointer b
print(b)  # Pointer b points to a DIFFERENT container that just has the same list values as a's container
b[0] = 7  # Modify first item in the SECOND container via pointer b
print(a)  # Pointer a still points to the first container 
print(b)  # Pointer b still points to the second container

# %% [markdown]
# *Note*: Blank slicing a list - `[:]` - creates a copy of that list.

# %% [markdown]
# Check out even more crazy stuff you can do in Python:
#
# https://github.com/satwikkansal/wtfpython

# %% [markdown]
# ## Tuples
#
# - Similar to lists
# - Can contain duplicates
# - Immutable
# - Defined by ``(1, 2, 3)`` or simply ``1, 2, 3``

# %%
t = (1, 2, 3)
t

# %%
t = 1, 2, 3
t

# %%
len(t)

# %% [markdown]
# ### Elements cannot be changed
#
# ```python
# t[0] = 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-6dd06f73cec4> in <module>()
# ----> 1 t[0] = 5
#
# TypeError: 'tuple' object does not support item assignment
# ```

# %% [markdown]
# ### Return types of functions are often tuples

# %%
x = 0.125
x.as_integer_ratio()

# %%
numerator, denominator = x.as_integer_ratio()
numerator / denominator

# %% [markdown]
# ## Sets
# - Unordered collections of unique items
# - Support set operations
# - Defined by ``{1, 2, 3}``

# %%
primes = {2, 3, 5, 7}
odds = {1, 3, 5, 7, 9}

# %% [markdown]
# ### Union
# items appearing in either set

# %%
primes = {2, 3, 5, 7}
odds = {1, 3, 5, 7, 9}
primes | odds      # with an operator
primes.union(odds) # equivalently with a method

# %% [markdown]
# ### Intersection
# items appearing in both sets

# %%
primes = {2, 3, 5, 7}
odds = {1, 3, 5, 7, 9}
primes & odds             # with an operator
primes.intersection(odds) # equivalently with a method

# %% [markdown]
# ### Difference
# items appearing in one but not other set

# %%
primes = {2, 3, 5, 7}
odds = {1, 3, 5, 7, 9}
primes - odds           # with an operator
primes.difference(odds) # equivalently with a method

# %% [markdown]
# ### Symmetric difference
# items appearing in only one set

# %%
primes = {2, 3, 5, 7}
odds = {1, 3, 5, 7, 9}
primes ^ odds                     # with an operator
primes.symmetric_difference(odds) # equivalently with a method

# %% [markdown]
# ## Dictionaries
# - Hash table
# - Extremely flexible and versatile
# - Fast access
# - Unordered
# - Defined by ``key:value`` pairs within curly braces: ``{'a':1, 'b':2, 'c':3}``

# %%
numbers = {'one':1, 'two':2, 'three':3}
val2num = {v:k for k,v in numbers.items()}
val2num

# %%
numbers.values()

# %%
# Access a value via the key
numbers['two']

# %%
# Set a new key:value pair
numbers['ninety'] = 90
numbers

# %% [markdown]
# ## Type Hints
#
# - Python is a **dynamically typed** language, meaning you don't need to declare variable types
# - **type hints** (also called **type annotations**) allow you to:
#
#     * Improve code readability
#     * Enable better IDE autocomplete and error detection
#     * Facilitate static type checking (using tools like `mypy`)
#     * Serve as documentation
#
# **Important**: Type hints are **optional** and don't affect runtime behavior. Python remains dynamically typed.

# %%
# Without type hints
def greet(name):
    return f"Hello, {name}!"

# With type hints
def greet_typed(name: str) -> str:
    return f"Hello, {name}!"

print(greet("Alice"))
print(greet_typed("Bob"))

# Type hints don't prevent this from running (but mypy would flag it)
print(greet_typed(123))  # Works at runtime!

# %% [markdown]
# ## Basic Type Annotations
#
# ### Built-in Types
#
# Python's built-in types can be used directly for annotations:
#
# | Type | Description | Example |
# |------|-------------|----------|
# | `int` | Integer | `age: int = 25` |
# | `float` | Floating point | `price: float = 19.99` |
# | `str` | String | `name: str = "Alice"` |
# | `bool` | Boolean | `is_active: bool = True` |
# | `bytes` | Byte string | `data: bytes = b"hello"` |
# | `None` | None type | `result: None = None` |

# %%
# Variable annotations
name: str = "Alice"
age: int = 30
height: float = 170
is_student: bool = False

print(f"{name} is {age} years old, {height} cm tall")
print(f"Student status: {is_student}")

# You can also annotate without assignment
country: str
country = "Germany"  # Assigned later
print(f"Country: {country}")

# %% [markdown]
# ## Collection Types
#
# For collections, we use the `typing` module to specify the types of elements they contain.
#
# ### Python 3.9+ (Simplified Syntax)

# %%
# Lists
numbers: list[int] = [1, 2, 3, 4, 5]
names: list[str] = ["Alice", "Bob", "Charlie"]

# Dictionaries
scores: dict[str, int] = {"Alice": 95, "Bob": 87}
config: dict[str, str] = {"host": "localhost", "port": "8080"}

# Sets
unique_ids: set[int] = {1, 2, 3, 4, 5}

# Tuples (fixed size)
coordinates: tuple[float, float] = (10.5, 20.3)
rgb_color: tuple[int, int, int] = (255, 128, 0)

# Tuples (variable size)
variable_tuple: tuple[int, ...] = (1, 2, 3, 4, 5)

# %%
from typing import List, Dict, Set, Tuple

# For Python < 3.9, use capital letter versions from typing
old_style_list: List[int] = [1, 2, 3]
old_style_dict: Dict[str, float] = {"pi": 3.14, "e": 2.71}
old_style_set: Set[str] = {"apple", "banana", "cherry"}
old_style_tuple: Tuple[str, int, bool] = ("Alice", 30, True)

print(f"Old style list: {old_style_list}")
print(f"Old style dict: {old_style_dict}")

# %% [markdown]
# # Python Data Types and Collections Exercises
#
# ## Exercise 1: List Manipulation
# Write a function `manipulate_list(lst)` that takes a list of integers and returns a new list containing only the even numbers, doubled.
# - **Example**:
#   - Input: `[1, 2, 3, 4, 5]`
#   - Output: `[4, 8]`
#
# ## Exercise 2: Dictionary Key-Value Swap
# Create a function `swap_dict(d)` that takes a dictionary and returns a new dictionary with keys and values swapped.
# - **Example**:
#   - Input: `{'a': 1, 'b': 2}`
#   - Output: `{1: 'a', 2: 'b'}`
#
# ## Exercise 3: Tuple Unpacking
# Write a function `tuple_operations(tpl)` that takes a tuple of three elements (a string, an integer, and a float) and returns a formatted string summarizing its contents.
# - **Example**:
#   - Input: `('apple', 5, 3.14)`
#   - Output: `'The string is apple, the integer is 5, and the float is 3.14.'`
#
# ## Exercise 4: Set Operations
# Implement a function `set_operations(set_a, set_b)` that takes two sets and returns a tuple containing their union, intersection, and difference.
# - **Example**:
#   - Input: `({1, 2, 3}, {2, 3, 4})`
#   - Output: `({1, 2, 3, 4}, {2, 3}, {1})`
#
# ## Exercise 5: List Comprehension
# Create a function `square_numbers(n)` that returns a list of the squares of the first `n` positive integers using list comprehension.
# - **Example**:
#   - Input: `5`
#   - Output: `[1, 4, 9, 16, 25]`
#
# ## Exercise 6: Membership Testing
# Write a function `check_membership(value, collection)` that checks if a value is present in a collection (list, set, or dictionary keys) and returns a corresponding message.
# - **Example**:
#   - Input: `check_membership(3, [1, 2, 3, 4])`
#   - Output: `'3 is in the collection.'`
#
# ## Exercise 7: Nested Collections
# Implement a function `get_student_grades(students)` that takes a list of dictionaries containing student names and their grades. Return a list of tuples containing the student names and their average grades.
# - **Example**:
#   - Input: `[{'name': 'Alice', 'grades': [90, 80]}, {'name': 'Bob', 'grades': [70, 60]}]`
#   - Output: `[('Alice', 85.0), ('Bob', 65.0)]`
#
# ## Exercise 8: Filtering Dictionaries
# Write a function `filter_dict_by_value(d, threshold)` that removes all key-value pairs from a dictionary where the value is less than the given threshold.
# - **Example**:
#   - Input: `filter_dict_by_value({'a': 10, 'b': 5, 'c': 8}, 7)`
#   - Output: `{'a': 10, 'c': 8}`
#
# ## Exercise 9: String to List Conversion
# Create a function `string_to_list(s)` that converts a comma-separated string into a list of integers.
# - **Example**:
#   - Input: `'1,2,3,4'`
#   - Output: `[1, 2, 3, 4]`
#
# ## Exercise 10: Counting Elements
# Write a function `count_elements(collection)` that takes a collection (list, set, or string) and returns a dictionary with the count of each unique element.
# - **Example**:
#   - Input: `count_elements(['apple', 'banana', 'apple'])`
#   - Output: `{'apple': 2, 'banana': 1}`
